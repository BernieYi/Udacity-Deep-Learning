# %% [markdown]
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.
# "count" is a list which order the words by its frequency desc;
# "data" is the digitalized version of the text which uses the frequency sequence in the "count" list to represent each word in original text;
# "dictionary" is the mapping between specific "word" and its "sequence' in term of usage frequency;  It maps the originla text into "data" view.
# "reverse_dictionary" uses "sequence" as the key and "word" as value. It is used to find the word according to the "sequence".

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'of', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.962324
# Nearest to be: maulana, user, fits, rouge, unfamiliar, eindhoven, groucho, comedians,
# Nearest to seven: harrier, reissue, sejanus, couplet, screenplays, pursues, null, monadic,
# Nearest to world: aired, obese, wim, cretan, seal, historicity, macromedia, euripides,
# Nearest to after: angie, epitomized, hur, telegraphs, annexing, rhinoceros, doo, warfield,
# Nearest to than: eugen, clairvoyance, transcendent, guanosine, azali, yellowstone, conduit, frigg,
# Nearest to while: combinatorial, conceive, ata, ullman, gam, blast, appointment, prc,
# Nearest to into: rightarrow, confucian, delineation, kongo, armenians, kern, stunted, directions,
# Nearest to have: caledonian, refracted, waid, canary, holdings, stylization, praised, slots,
# Nearest to one: botswana, wilkes, bags, eradicating, panspermia, picirilli, consumes, polemical,
# Nearest to such: jen, prosaic, darth, bombed, untouchables, notables, weaver, hall,
# Nearest to not: parochial, pat, existed, racehorse, liliuokalani, adolph, meltzer, friendly,
# Nearest to his: infidel, santander, pills, modelled, gem, categorize, yelling, suddenly,
# Nearest to of: militants, stephan, official, verbatim, barkley, impair, lrv, sasaki,
# Nearest to or: nilpotent, camino, moldavia, outperform, palma, camera, malik, dei,
# Nearest to during: hiddenstructure, cryogenic, placenta, dominic, reinstating, rus, primed, bills,
# Nearest to so: suppression, druidry, sense, snegur, maharaja, gallon, yung, valve,
# Average loss at step 2000: 4.368002
# Average loss at step 4000: 3.864206
# Average loss at step 6000: 3.786081
# Average loss at step 8000: 3.687273
# Average loss at step 10000: 3.609856
# Nearest to be: have, maulana, is, been, was, make, were, asphyxiation,
# Nearest to seven: six, five, eight, three, four, nine, zero, two,
# Nearest to world: seal, kushan, manned, obese, cretan, shona, trintignant, drake,
# Nearest to after: epitomized, turret, furthered, unspecified, before, bicycle, champ, rhinoceros,
# Nearest to than: or, publically, crime, discreet, guanosine, mounds, proudhon, patricio,
# Nearest to while: combinatorial, gam, kilgore, ullman, chiropractors, persisted, ata, conceive,
# Nearest to into: rightarrow, since, from, delineation, kern, redirect, macrostate, humiliated,
# Nearest to have: has, be, had, are, were, jeffersonian, hedley, solemnly,
# Nearest to one: three, two, four, six, eight, five, seven, nine,
# Nearest to such: well, enumerated, emma, infecting, prosaic, swastika, billing, ceremony,
# Nearest to not: it, normally, they, to, also, grasso, generally, often,
# Nearest to his: their, her, the, belarusian, s, its, diagonal, prescriptions,
# Nearest to of: in, sasaki, at, for, pennants, unsound, hellenized, from,
# Nearest to or: and, lozada, than, sahelian, abdal, anthrax, mannerheim, notoc,
# Nearest to during: elucidated, adventure, on, in, rus, joannes, cuttlefish, bills,
# Nearest to so: percentile, druidry, suppression, if, sense, putty, issa, sleeve,
# Average loss at step 12000: 3.603125
# Average loss at step 14000: 3.565527
# Average loss at step 16000: 3.410418
# Average loss at step 18000: 3.460870
# Average loss at step 20000: 3.543543
# Nearest to be: have, been, is, was, become, were, make, fabricated,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to world: seal, obese, shona, temples, cretan, geoffrey, kushan, ablation,
# Nearest to after: before, epitomized, basayev, furthered, turret, during, from, since,
# Nearest to than: or, publically, crime, wavering, guanosine, franconia, technically, resists,
# Nearest to while: combinatorial, hodge, incompetent, specimen, qua, coup, maoists, gam,
# Nearest to into: from, rightarrow, since, redirect, by, delineation, against, reopened,
# Nearest to have: had, has, be, are, were, having, jeffersonian, allow,
# Nearest to one: four, two, three, seven, eight, five, six, nine,
# Nearest to such: well, enumerated, emma, known, these, swastika, crises, refutable,
# Nearest to not: it, normally, they, also, to, this, incidental, you,
# Nearest to his: their, her, its, the, belarusian, prescriptions, greta, asser,
# Nearest to of: sasaki, saab, for, novgorod, aar, dunham, increases, lrv,
# Nearest to or: and, than, with, though, notoc, palos, lodging, splendid,
# Nearest to during: in, elucidated, on, adventure, after, enclosures, placenta, synchronization,
# Nearest to so: percentile, too, druidry, suppression, if, disengage, putty, hurley,
# Average loss at step 22000: 3.503474
# Average loss at step 24000: 3.487500
# Average loss at step 26000: 3.479049
# Average loss at step 28000: 3.480159
# Average loss at step 30000: 3.503131
# Nearest to be: have, been, were, conspicuously, was, continue, try, is,
# Nearest to seven: five, eight, six, nine, four, three, two, zero,
# Nearest to world: seal, obese, temples, dynamic, trintignant, geoffrey, impair, shona,
# Nearest to after: before, during, from, when, since, falco, at, for,
# Nearest to than: publically, or, wavering, resists, no, hamish, crime, internetwork,
# Nearest to while: is, but, however, drpg, maoists, atonality, are, mayr,
# Nearest to into: from, through, rightarrow, since, redirect, macrostate, under, around,
# Nearest to have: had, has, are, were, having, be, rightarrow, allow,
# Nearest to one: two, seven, four, three, six, five, eight, nine,
# Nearest to such: well, emma, these, known, enumerated, swastika, some, infecting,
# Nearest to not: they, normally, there, still, it, also, generally, we,
# Nearest to his: their, her, its, the, s, guyana, belarusian, prescriptions,
# Nearest to of: in, from, and, pennants, saab, for, mammary, including,
# Nearest to or: and, than, com, lozada, as, directs, abdal, but,
# Nearest to during: after, in, on, elucidated, until, at, ukrainian, before,
# Nearest to so: too, percentile, hurley, pickup, qxd, issa, shires, disengage,
# Average loss at step 32000: 3.502389
# Average loss at step 34000: 3.494273
# Average loss at step 36000: 3.458273
# Average loss at step 38000: 3.306665
# Average loss at step 40000: 3.425545
# Nearest to be: been, have, is, conspicuously, being, become, continue, rouge,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to world: obese, u, country, ecma, robbed, talked, trintignant, shona,
# Nearest to after: before, during, falco, when, from, since, upkeep, without,
# Nearest to than: or, wavering, publically, dey, crime, halted, no, hamish,
# Nearest to while: although, but, when, delivers, were, however, drpg, though,
# Nearest to into: through, from, rightarrow, around, database, redirect, delineation, ayub,
# Nearest to have: had, has, were, are, be, having, rightarrow, achieve,
# Nearest to one: six, seven, two, eight, four, five, three, nine,
# Nearest to such: well, known, these, emma, enumerated, swastika, certain, described,
# Nearest to not: normally, they, still, never, it, often, haunting, we,
# Nearest to his: her, their, its, the, my, guyana, your, s,
# Nearest to of: in, from, mbeki, stratification, plunges, kerguelen, saab, daytona,
# Nearest to or: and, than, a, universitaire, exons, assembling, com, shepherds,
# Nearest to during: after, before, at, on, in, until, elucidated, first,
# Nearest to so: percentile, too, pickup, shires, hurley, qxd, fei, claimed,
# Average loss at step 42000: 3.435940
# Average loss at step 44000: 3.456001
# Average loss at step 46000: 3.453471
# Average loss at step 48000: 3.354429
# Average loss at step 50000: 3.387716
# Nearest to be: have, was, been, being, were, is, are, become,
# Nearest to seven: six, eight, four, nine, three, five, zero, two,
# Nearest to world: obese, robbed, trintignant, shona, country, ecma, u, ezekiel,
# Nearest to after: before, during, when, despite, from, while, without, falco,
# Nearest to than: or, but, wavering, publically, no, eidyn, dey, resists,
# Nearest to while: although, when, but, however, though, and, where, after,
# Nearest to into: through, from, around, under, ayub, kimball, within, laborer,
# Nearest to have: had, has, were, are, be, having, rightarrow, ve,
# Nearest to one: two, six, four, seven, three, eight, five, nine,
# Nearest to such: well, known, emma, these, swastika, enumerated, regarded, many,
# Nearest to not: normally, we, they, usually, still, never, now, it,
# Nearest to his: her, their, its, my, your, the, s, ferro,
# Nearest to of: in, aar, including, induce, for, saab, piled, and,
# Nearest to or: and, com, than, etymology, termite, capturing, exons, any,
# Nearest to during: after, in, at, before, elucidated, on, following, mal,
# Nearest to so: too, percentile, budd, shires, fei, epr, dtp, thus,
# Average loss at step 52000: 3.436949
# Average loss at step 54000: 3.427930
# Average loss at step 56000: 3.440195
# Average loss at step 58000: 3.398393
# Average loss at step 60000: 3.396020
# Nearest to be: been, being, was, become, refer, have, alkynes, is,
# Nearest to seven: eight, four, six, five, nine, three, one, zero,
# Nearest to world: obese, trintignant, country, arabized, coerce, robbed, talked, radiotelephone,
# Nearest to after: before, during, when, despite, without, cameraman, following, from,
# Nearest to than: but, and, wavering, publically, or, halted, internetwork, existentialist,
# Nearest to while: although, when, though, but, before, where, were, however,
# Nearest to into: through, from, around, in, within, rightarrow, under, pinch,
# Nearest to have: has, had, were, achieve, are, rightarrow, having, ve,
# Nearest to one: four, two, seven, eight, three, six, five, nine,
# Nearest to such: well, known, these, emma, regarded, swastika, many, described,
# Nearest to not: still, normally, they, we, kangchenjunga, macclesfield, usually, you,
# Nearest to his: her, their, its, my, your, the, lagos, our,
# Nearest to of: in, for, although, calming, aar, kerguelen, from, gascon,
# Nearest to or: and, com, but, lego, than, fitna, krieger, technocrats,
# Nearest to during: after, in, before, following, although, despite, within, until,
# Nearest to so: percentile, too, something, fei, budd, epr, sometimes, disengage,
# Average loss at step 62000: 3.239453
# Average loss at step 64000: 3.256589
# Average loss at step 66000: 3.407181
# Average loss at step 68000: 3.395190
# Average loss at step 70000: 3.360022
# Nearest to be: been, being, were, is, become, was, refer, have,
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to world: obese, country, robbed, ezekiel, u, trintignant, arabized, ecma,
# Nearest to after: before, during, despite, when, without, cameraman, while, excommunicating,
# Nearest to than: or, but, wavering, publically, hamish, halted, dey, and,
# Nearest to while: although, though, when, however, but, where, before, and,
# Nearest to into: through, from, around, kimball, pinch, pellets, within, laborer,
# Nearest to have: had, has, were, are, having, rightarrow, achieve, be,
# Nearest to one: two, six, four, seven, eight, three, five, nine,
# Nearest to such: these, well, known, emma, many, swastika, regarded, including,
# Nearest to not: still, normally, never, now, kangchenjunga, generally, naturalists, usually,
# Nearest to his: her, their, its, my, your, our, guyana, lagos,
# Nearest to of: including, in, for, petrified, yule, aar, and, calming,
# Nearest to or: and, than, but, quota, rathdown, mimi, fitna, lego,
# Nearest to during: after, before, in, following, within, despite, until, through,
# Nearest to so: percentile, too, thus, therefore, pickup, druidry, epr, fei,
# Average loss at step 72000: 3.376718
# Average loss at step 74000: 3.352737
# Average loss at step 76000: 3.320091
# Average loss at step 78000: 3.357104
# Average loss at step 80000: 3.375773
# Nearest to be: been, being, contribute, become, alkynes, have, is, refer,
# Nearest to seven: four, six, eight, five, nine, three, zero, one,
# Nearest to world: u, robbed, obese, ezekiel, country, universe, arabized, uk,
# Nearest to after: before, during, despite, when, while, without, from, until,
# Nearest to than: or, much, but, wavering, eidyn, monotonous, even, hamish,
# Nearest to while: although, though, when, however, after, but, before, and,
# Nearest to into: through, from, within, around, kimball, pinch, under, across,
# Nearest to have: had, has, are, having, were, be, achieve, chose,
# Nearest to one: seven, two, six, four, three, eight, five, nine,
# Nearest to such: well, known, these, emma, swastika, regarded, certain, including,
# Nearest to not: still, they, you, never, normally, we, kangchenjunga, it,
# Nearest to his: her, their, my, its, your, our, bithynia, the,
# Nearest to of: including, seating, nola, apprentices, in, stratification, entire, gascon,
# Nearest to or: and, than, com, synchronize, cathal, termite, while, federko,
# Nearest to during: after, in, before, despite, until, through, when, within,
# Nearest to so: too, percentile, thus, therefore, druidry, fei, peacefully, something,
# Average loss at step 82000: 3.408854
# Average loss at step 84000: 3.413059
# Average loss at step 86000: 3.390533
# Average loss at step 88000: 3.354015
# Average loss at step 90000: 3.365650
# Nearest to be: been, refer, become, being, have, is, contribute, was,
# Nearest to seven: six, eight, four, nine, five, three, one, two,
# Nearest to world: country, universe, robbed, tehran, institutions, obese, cracow, ezekiel,
# Nearest to after: before, during, despite, when, while, until, without, through,
# Nearest to than: monotonous, wavering, or, publically, minced, dey, gallium, hamish,
# Nearest to while: although, when, before, after, though, during, however, but,
# Nearest to into: through, from, around, within, pellets, pinch, kimball, laborer,
# Nearest to have: had, has, are, were, having, be, tend, ve,
# Nearest to one: seven, two, four, eight, six, three, five, nine,
# Nearest to such: well, known, emma, these, swastika, certain, including, regarded,
# Nearest to not: still, they, we, generally, naturalists, never, normally, regularly,
# Nearest to his: her, their, its, your, my, our, the, bushes,
# Nearest to of: for, in, musab, saab, including, ultimate, calming, during,
# Nearest to or: and, cries, technocrats, com, than, though, but, vauxhall,
# Nearest to during: after, in, before, until, at, through, despite, while,
# Nearest to so: too, percentile, thus, druidry, therefore, peacefully, pickup, homeostasis,
# Average loss at step 92000: 3.397602
# Average loss at step 94000: 3.256609
# Average loss at step 96000: 3.358632
# Average loss at step 98000: 3.244080
# Average loss at step 100000: 3.363511
# Nearest to be: been, being, refer, are, become, is, have, contribute,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to world: country, robbed, obese, universe, game, u, ezekiel, cracow,
# Nearest to after: before, during, despite, when, while, until, without, through,
# Nearest to than: or, wavering, monotonous, eidyn, existentialist, openness, minced, diophantus,
# Nearest to while: although, when, after, though, however, but, before, where,
# Nearest to into: through, from, within, around, pinch, off, warmblood, across,
# Nearest to have: had, has, tend, are, were, having, contain, be,
# Nearest to one: two, four, five, three, eight, seven, six, nine,
# Nearest to such: known, well, emma, certain, regarded, many, these, maximally,
# Nearest to not: still, never, normally, almost, kangchenjunga, generally, it, also,
# Nearest to his: her, their, my, your, its, the, our, s,
# Nearest to of: including, saab, dah, in, calming, primary, gunpoint, titular,
# Nearest to or: and, than, com, synchronize, capturing, leigh, krs, though,
# Nearest to during: after, in, before, despite, when, through, throughout, within,
# Nearest to so: too, thus, percentile, peacefully, therefore, pickup, fei, then,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
