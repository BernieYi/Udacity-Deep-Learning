# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
print(data[:10])
print(count[:10])
print(list(dictionary.items())[:10])
print(list(reverse_dictionary.items())[:10])
# Out:
# [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('UNK', 0), ('the', 1), ('of', 2), ('and', 3), ('one', 4), ('in', 5), ('a', 6), ('to', 7), ('zero', 8), ('nine', 9)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Note the instruction change on the loss function, with reduce_sum to sum the word vectors in the context:
#
# How to debug here:
#
# "from IPython.core.debugger import set_trace"
# "set_trace()"
# "n - next()"
# "c- continue()"
# ...

# %%
#from IPython.core.debugger import set_trace

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  #set_trace()

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # Since the default sequence of the "sampled_softmax_loss()" function parameters have been changed, the label of each parameters
  # are required. 
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.903319
# Nearest to th: sealing, wade, kala, rushton, sfsr, rubicon, overcrowded, argentinean,
# Nearest to also: pohnpei, gordon, textile, durkheim, launcher, colic, adoptive, bayesian,
# Nearest to some: precolonial, ay, bout, wavell, neuroimaging, marge, lagging, perfecting,
# Nearest to can: ane, fairest, rb, unsuitable, minurso, specter, praying, hexafluoride,
# Nearest to after: inflate, ploy, inwardly, revolutions, abrupt, nearest, gladys, wtc,
# Nearest to than: viciously, interludes, academically, bribery, latinus, stateless, refraining, eisa,
# Nearest to b: stirrups, ride, garlic, bedfordshire, eclectic, kzin, zhuhai, compromise,
# Nearest to first: fulda, lifespans, weir, fung, bukovina, servicio, grattan, bolivia,
# Nearest to this: katie, vanessa, baumgarten, nadezhda, solicitors, meteoric, microwave, chalker,
# Nearest to he: tagus, qq, typology, ns, tfl, contesting, refreshed, nmos,
# Nearest to his: woodcut, etymologically, heyday, lupin, johnstone, hor, consorts, influx,
# Nearest to if: carrey, efficiently, scotsman, borgia, footage, millimetre, busta, doctrines,
# Nearest to while: joystick, scholz, aqaba, groundwater, sums, conservatively, germanium, unfairly,
# Nearest to in: guignol, coro, inscription, trier, blitzkrieg, bahnhof, prosecutor, occupations,
# Nearest to would: crucifix, summaries, organist, rebuilt, perverted, viscount, nuisance, turret,
# Nearest to at: conan, affixes, larnaca, gentiles, sleeves, usemodwiki, toughest, mcgowan,
# Average loss at step 2000: 4.470971
# Average loss at step 4000: 3.873710
# Average loss at step 6000: 3.766111
# Average loss at step 8000: 3.595178
# Average loss at step 10000: 3.555110
# Nearest to th: eight, seven, nine, kaohsiung, villainous, retrieving, conjugal, hostages,
# Nearest to also: which, partita, often, mothers, ebcdic, multivariate, phalanx, sorceress,
# Nearest to some: many, all, these, several, curonian, integrating, both, sheet,
# Nearest to can: would, may, will, could, should, must, might, cannot,
# Nearest to after: before, later, during, nearest, when, victor, until, lesion,
# Nearest to than: or, brahmins, rydberg, and, tabari, merrill, gotham, surge,
# Nearest to b: hdi, vicarious, stirrups, eclectic, compromise, predating, righteousness, triton,
# Nearest to first: nyasaland, nahuatl, proudly, aafc, second, aor, honorific, threaten,
# Nearest to this: it, any, which, hexagrams, an, the, breast, that,
# Nearest to he: she, it, they, who, adapt, qam, convents, necessitated,
# Nearest to his: her, their, its, cmb, the, s, mclachlan, esa,
# Nearest to if: scotsman, shareholders, fared, levantine, phnom, antiquark, mel, armed,
# Nearest to while: however, unfairly, dawning, drexler, but, dissemination, wounding, intellectually,
# Nearest to in: during, from, until, of, on, conjunctive, into, since,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to at: from, outcast, sampo, packaging, when, during, crucible, toughest,
# Average loss at step 12000: 3.535575
# Average loss at step 14000: 3.520258
# Average loss at step 16000: 3.367340
# Average loss at step 18000: 3.142991
# Average loss at step 20000: 3.217941
# Nearest to th: st, twentieth, firsthand, nineteenth, kaohsiung, nine, joab, retrieving,
# Nearest to also: below, now, often, which, cochran, compare, witted, comprise,
# Nearest to some: many, several, all, various, these, both, any, other,
# Nearest to can: could, will, should, would, cannot, must, may, might,
# Nearest to after: before, during, for, until, when, requested, following, had,
# Nearest to than: brahmins, but, merrill, lemay, or, tabari, rydberg, vil,
# Nearest to b: d, choctaw, motive, sympathizer, taxation, waid, brett, consciously,
# Nearest to first: last, second, same, next, honorific, intuitionistic, sounding, converse,
# Nearest to this: it, another, which, any, the, what, erp, idriss,
# Nearest to he: she, it, they, who, pelts, unrestrained, rub, cushitic,
# Nearest to his: her, their, its, the, cmb, mclachlan, entitlement, neoplatonic,
# Nearest to if: where, when, while, though, since, then, caa, hermaphrodite,
# Nearest to while: and, if, when, though, although, bulgarians, among, aluma,
# Nearest to in: during, within, grazed, on, scriptores, throughout, around, mommu,
# Nearest to would: will, could, must, should, may, can, might, cannot,
# Nearest to at: down, during, on, latins, mcgowan, automobiles, apostles, conan,
# Average loss at step 22000: 3.362755
# Average loss at step 24000: 3.220636
# Average loss at step 26000: 3.254784
# Average loss at step 28000: 3.313412
# Average loss at step 30000: 3.193071
# Nearest to th: nine, twentieth, st, nineteenth, mut, nd, antagonism, inflate,
# Nearest to also: now, often, never, what, freebsd, where, eof, which,
# Nearest to some: many, several, any, various, most, both, those, no,
# Nearest to can: may, could, should, will, must, would, cannot, might,
# Nearest to after: before, following, during, when, for, admiring, until, lesion,
# Nearest to than: but, brahmins, while, or, lemay, epsilon, mesolithic, tabari,
# Nearest to b: d, cthulhu, queries, timberlake, dur, falsifiable, knocks, subordinates,
# Nearest to first: last, second, final, same, converse, third, intuitionistic, honorific,
# Nearest to this: it, any, another, bounding, which, the, a, what,
# Nearest to he: she, it, they, wiktionary, who, pelts, asparagales, aristotle,
# Nearest to his: her, their, its, the, s, mclachlan, my, enrico,
# Nearest to if: when, though, since, where, before, must, surfacing, natalia,
# Nearest to while: although, though, when, however, like, and, among, where,
# Nearest to in: within, during, throughout, since, azrael, on, among, kofi,
# Nearest to would: will, could, should, may, must, can, might, did,
# Nearest to at: during, mcgowan, jaya, recited, within, packaging, latins, contemporaneously,
# Average loss at step 32000: 3.165802
# Average loss at step 34000: 3.148988
# Average loss at step 36000: 3.067583
# Average loss at step 38000: 3.082240
# Average loss at step 40000: 3.102035
# Nearest to th: twentieth, nd, nineteenth, st, mut, nine, culminated, retrieving,
# Nearest to also: often, now, below, still, freebsd, never, formulae, here,
# Nearest to some: many, several, various, these, most, all, both, those,
# Nearest to can: may, should, must, could, will, would, cannot, might,
# Nearest to after: before, during, following, until, afterwards, despite, swallowed, admiring,
# Nearest to than: or, brahmins, and, mesolithic, tabari, while, but, epsilon,
# Nearest to b: d, polygamous, waid, centralisation, watcher, proscribed, consciously, swore,
# Nearest to first: last, second, same, next, final, third, sounding, entire,
# Nearest to this: another, which, it, the, what, any, that, rpp,
# Nearest to he: she, it, they, pelts, wiktionary, previously, qam, hitler,
# Nearest to his: her, their, my, its, the, s, whose, your,
# Nearest to if: though, where, when, because, therefore, since, thus, what,
# Nearest to while: although, and, like, but, though, among, where, or,
# Nearest to in: within, during, throughout, from, since, until, when, through,
# Nearest to would: will, may, could, should, must, might, can, did,
# Nearest to at: mcgowan, near, during, from, in, contemporaneously, magnified, repent,
# Average loss at step 42000: 3.096580
# Average loss at step 44000: 3.137636
# Average loss at step 46000: 3.092988
# Average loss at step 48000: 2.977785
# Average loss at step 50000: 3.104548
# Nearest to th: twentieth, st, nineteenth, nd, rd, antagonism, carmichael, galante,
# Nearest to also: often, still, actually, below, now, which, when, here,
# Nearest to some: many, several, various, all, both, certain, these, norte,
# Nearest to can: may, must, should, could, will, might, cannot, would,
# Nearest to after: before, during, despite, following, afterwards, since, until, verlag,
# Nearest to than: or, but, brahmins, darkly, lamenting, mesolithic, confidently, aiki,
# Nearest to b: d, salesman, watcher, supine, r, infrastructural, sinclair, f,
# Nearest to first: last, next, second, same, final, entire, previous, third,
# Nearest to this: it, another, which, what, the, idriss, a, unchangeable,
# Nearest to he: she, it, they, who, qam, never, tillman, elvish,
# Nearest to his: their, her, its, the, my, your, s, our,
# Nearest to if: when, because, where, though, patriarchal, thus, here, bixby,
# Nearest to while: although, and, but, because, though, among, however, once,
# Nearest to in: during, within, throughout, since, through, around, until, mommu,
# Nearest to would: could, will, must, might, should, can, may, cannot,
# Nearest to at: mcgowan, repent, jaya, recited, crucible, near, asbury, robbery,
# Average loss at step 52000: 3.070735
# Average loss at step 54000: 3.061983
# Average loss at step 56000: 3.081624
# Average loss at step 58000: 3.005589
# Average loss at step 60000: 2.830717
# Nearest to th: twentieth, nd, st, nineteenth, rd, third, seventeenth, antagonism,
# Nearest to also: now, below, still, often, currently, disambiguation, generally, staub,
# Nearest to some: many, several, numerous, various, all, these, most, certain,
# Nearest to can: may, must, could, might, should, cannot, would, will,
# Nearest to after: before, during, when, following, afterwards, verlag, since, upon,
# Nearest to than: brahmins, darkly, garonne, lamenting, even, epsilon, brady, but,
# Nearest to b: d, r, f, babbitt, x, computationally, p, c,
# Nearest to first: last, second, same, next, third, best, final, fourth,
# Nearest to this: which, it, another, what, that, rasterization, confessional, idriss,
# Nearest to he: she, it, they, who, embroidery, eventually, pelts, fragmentary,
# Nearest to his: her, their, its, my, the, s, our, your,
# Nearest to if: when, though, patriarchal, where, because, before, what, must,
# Nearest to while: although, including, and, among, however, when, before, but,
# Nearest to in: within, throughout, during, since, until, on, before, azrael,
# Nearest to would: will, could, should, must, might, may, can, did,
# Nearest to at: mcgowan, katsura, packaging, crucible, contemporaneously, casale, historia, near,
# Average loss at step 62000: 3.020289
# Average loss at step 64000: 3.009857
# Average loss at step 66000: 2.995515
# Average loss at step 68000: 3.015114
# Average loss at step 70000: 3.060701
# Nearest to th: twentieth, st, nineteenth, nd, rd, eighteenth, seventeenth, kreutzmann,
# Nearest to also: disambiguation, below, still, actually, now, which, currently, where,
# Nearest to some: many, several, various, certain, both, multiple, numerous, cinco,
# Nearest to can: could, must, may, should, would, will, cannot, might,
# Nearest to after: before, when, during, afterwards, despite, since, following, until,
# Nearest to than: but, brahmins, garonne, sharada, tabari, unlike, announcing, or,
# Nearest to b: d, c, babbitt, r, sup, f, swamped, swordfish,
# Nearest to first: last, next, second, third, final, best, earliest, previous,
# Nearest to this: it, which, what, another, the, she, a, idriss,
# Nearest to he: she, it, they, who, netting, melchior, there, embroidery,
# Nearest to his: her, their, its, my, your, our, s, gloom,
# Nearest to if: where, when, though, since, because, unless, although, patriarchal,
# Nearest to while: although, however, though, when, but, and, where, including,
# Nearest to in: within, throughout, during, on, where, until, outside, since,
# Nearest to would: could, will, should, might, can, may, must, cannot,
# Nearest to at: near, mcgowan, during, in, casale, on, over, zuse,
# Average loss at step 72000: 3.008388
# Average loss at step 74000: 3.018757
# Average loss at step 76000: 2.921713
# Average loss at step 78000: 2.929220
# Average loss at step 80000: 2.984652
# Nearest to th: twentieth, nd, nineteenth, st, third, rd, eighteenth, fourth,
# Nearest to also: disambiguation, still, now, below, actually, currently, which, indeed,
# Nearest to some: many, several, various, numerous, certain, both, these, most,
# Nearest to can: may, could, must, should, cannot, would, might, will,
# Nearest to after: before, afterwards, following, during, despite, when, since, retroviral,
# Nearest to than: or, but, brahmins, lamenting, reaches, unlike, allocating, became,
# Nearest to b: d, nmr, putative, tall, insulinotherapy, grunwald, illa, oud,
# Nearest to first: last, next, final, second, third, fourth, best, latter,
# Nearest to this: it, which, what, the, that, a, each, another,
# Nearest to he: she, it, they, presto, qam, who, wiktionary, i,
# Nearest to his: her, their, its, our, my, the, s, your,
# Nearest to if: when, though, because, until, therefore, where, although, instrumentals,
# Nearest to while: although, and, though, but, however, when, morals, where,
# Nearest to in: within, throughout, during, when, into, since, buggery, among,
# Nearest to would: could, will, might, may, should, must, can, cannot,
# Nearest to at: mcgowan, near, during, contemporaneously, in, towards, legalised, dachau,
# Average loss at step 82000: 2.967763
# Average loss at step 84000: 2.814226
# Average loss at step 86000: 2.917057
# Average loss at step 88000: 2.939808
# Average loss at step 90000: 2.935248
# Nearest to th: twentieth, nd, nineteenth, st, third, nine, rd, eighteenth,
# Nearest to also: below, disambiguation, often, never, still, actually, primarily, phalanx,
# Nearest to some: many, several, various, numerous, certain, these, multiple, all,
# Nearest to can: must, could, may, will, should, cannot, would, might,
# Nearest to after: before, despite, following, during, afterwards, when, since, post,
# Nearest to than: or, but, brahmins, mesolithic, unlike, reaches, epsilon, hand,
# Nearest to b: d, babbitt, insulinotherapy, reversible, titular, brackish, tall, oud,
# Nearest to first: last, next, second, third, earliest, same, final, debut,
# Nearest to this: it, which, what, the, another, idriss, carlyle, larmor,
# Nearest to he: she, it, they, qam, presto, wiktionary, already, kimberley,
# Nearest to his: her, their, its, our, my, your, s, whose,
# Nearest to if: when, though, since, until, where, because, before, patriarchal,
# Nearest to while: although, though, where, because, however, but, and, when,
# Nearest to in: during, throughout, within, around, from, since, near, outside,
# Nearest to would: will, could, might, should, must, can, may, cannot,
# Nearest to at: near, mcgowan, during, until, toward, in, among, dachau,
# Average loss at step 92000: 2.819805
# Average loss at step 94000: 2.832746
# Average loss at step 96000: 2.871980
# Average loss at step 98000: 2.922180
# Average loss at step 100000: 2.829152
# Nearest to th: twentieth, st, nineteenth, nd, eighteenth, fourth, antagonism, third,
# Nearest to also: below, now, still, disambiguation, currently, actually, which, generally,
# Nearest to some: many, several, certain, various, most, numerous, both, all,
# Nearest to can: could, cannot, will, should, must, may, might, would,
# Nearest to after: before, despite, when, during, following, afterwards, since, for,
# Nearest to than: unlike, brahmins, or, even, but, lamenting, garonne, mishnaic,
# Nearest to b: d, jewellery, babbitt, scientist, apostol, gradualism, lambert, tall,
# Nearest to first: last, second, next, earliest, best, third, original, same,
# Nearest to this: it, that, another, which, what, main, nullification, a,
# Nearest to he: she, it, they, previously, qam, who, netting, endeavoured,
# Nearest to his: her, their, its, my, your, the, s, our,
# Nearest to if: when, though, before, where, since, unless, after, because,
# Nearest to while: although, when, however, though, and, after, unlike, but,
# Nearest to in: throughout, during, within, on, since, at, conjunctive, across,
# Nearest to would: will, could, might, should, may, must, cannot, can,
# Nearest to at: near, mcgowan, during, in, towards, since, within, barca,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
